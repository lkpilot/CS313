# %% [markdown]
# # Loading Model
# Model `timpal0l/mdeberta-v3-base-squad2` sẽ được load từ HuggingFace cùng với các thông số cài đặt trước để chuẩn bị cho bước huấn luyện và đánh giá.

# %%
# !pip install -q datasets bitsandbytes accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 52.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.

# %%
import os
import torch
from datasets import DatasetDict, Dataset
from transformers import (
    AutoModelForQuestionAnswering,
    AutoModel,
    AutoTokenizer,
    BertTokenizerFast,
    BitsAndBytesConfig,
    logging
)

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"
logging.set_verbosity_error()

# %% [markdown]
# # Load dữ liệu để đánh giá model trước và sau khi sử dụng support database

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Support Database từ file .pkl đã lưu

# %%
# !pip install pinecone-client
# Out:
# Collecting pinecone-client
#   Downloading pinecone_client-4.1.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.2.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.12.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.0.7)
# Installing collected packages: pinecone-client
# Successfully installed pinecone-client-4.1.0

# %%
import pickle
with open('/content/drive/MyDrive/Nhom_2/Nhóm 2.2/Đồ án/new_vectors.pkl', 'rb') as f:
  # Load the data from the file
  data = pickle.load(f)

# %%
from google.colab import userdata
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(
    api_key=userdata.get('PINECONE_API_KEY')
)

# %% [markdown]
# ### Upload dữ liệu vào Pinecone (đã thực hiện, không cần lặp lại)

# %%
# Create new index if not existed
if 'vta-mooccubex-db' not in pc.list_indexes():
    pc.create_index(
        name='vta-mooccubex-db',
        dimension=768,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# %%
# Upload data
# Since data has been uploaded to Pinecone we can skip this step
from tqdm.auto import tqdm

for d in tqdm(data[53272:], total=len(data[53272:])):
    try:
        index.upsert(vectors=[d])
    except:
        continue
# Out:
#   0%|          | 0/74780 [00:00<?, ?it/s]

# %% [markdown]
# ### Load dữ liệu từ Pinecone

# %%
# Connect to index
index = pc.Index('vta-mooccubex-db')

# %%
# Example of a query
import numpy as np

db_token = "BAAI/bge-base-zh"

db_tokenizer = AutoTokenizer.from_pretrained(db_token, trust_remote_code=True)
db_model = AutoModel.from_pretrained('BAAI/bge-base-zh')
db_model.eval()

query = "储存单位有哪些"
query_embedded = db_tokenizer(query, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = db_model(**query_embedded)
    # Perform pooling. In this case, cls pooling.
    sentence_embeddings = model_output[0][:, 0]
# normalize embeddings
query_vector = torch.nn.functional.normalize(sentence_embeddings, p=2, dim=1)
# Out:
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/439k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/940 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/409M [00:00<?, ?B/s]

# %%
# Send the query to Pinecone
xc = index.query(vector=query_vector.tolist(), top_k=5, include_metadata=True)
xc
# Out:
# {'matches': [{'id': 'E0C76E1BDB560A3F9C33DC5901307461-2',
#               'metadata': {'text': '一个是存，'},
#               'score': 0.835356295,
#               'values': []},
#              {'id': 'B7A5E8BB1ECEE0FE9C33DC5901307461-0',
#               'metadata': {'text': '大家好 本视频介绍文件的存储'},
#               'score': 0.815917969,
#               'values': []},
#              {'id': '7FA1DCCC871E1E3C9C33DC5901307461-1',
#               'metadata': {'text': '。'},
#               'score': 0.801943719,
#               'values': []},
#              {'id': 'C6A3B36B193749E99C33DC5901307461-0',
#               'metadata': {'text': '各位同学，'},
#               'score': 0.797219694,
#               'values': []},
#              {'id': 'D854C076DDCB927A9C33DC5901307461-1',
#               'metadata': {'text': '储蓄存款就是居民个人的存款个人的存款又可以分为居民的活期储蓄存款和定期储蓄存款另外再加上一项是定期存款这个定期存款主要是指企事业单位的定期存款另外再加上其他存款这个其他存款比如说保证金存款是算作其他存款的截止到2015年10月底我们从统计的量来看中国人民银行大家如果去中国人民银行的网站每个月人民银行都会公布M0M1和M2的数据到2015年10月底的数据显示中国的M2已经超过136万亿元其中流通当中的现金流通当中的现金也就是人民银行发行的纸币和硬币在我们企业和个人手里所持有的主要大家注意一下是企业和个人手里所持有的这部分纸币和硬币加起来大概只占M2的比重的4.4%左右那剩下的都是什么剩下的都是存款包括企业的活期存款企业的定期存款和居民的储蓄存款再加上其他存款所以，从这里我们可以看到现代意义上央行的统计口径中所谓的货币或者说货币供应量主要是存款占了绝大多数而我们手里持有的人民币现金或者是说硬币，'},
#               'score': 0.797144175,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %% [markdown]
# ## Load dữ liệu đánh giá

# %%
# !git clone https://github.com/khanh232002/VTA-dataset --quiet

import pandas as pd
from datasets import Dataset, DatasetDict
qa = pd.read_csv('VTA-dataset/vta_qa.csv')
qa
# Out:
#           id         question  \
# 0      24925               试探
# 1      24926             线性试探
# 2      24956          什么是C语言？
# 3      25115          二进制转十进制
# 4      25268          计算机科学技术
# ...      ...              ...
# 1867  136281       计算有什么一般特点？
# 1868  136282          什么是图灵机？
# 1869  136331         什么是操作系统？
# 1870  136370   Windows中的安全配置:
# 1871  136371  Web、FTP服务器的安全配置
#
#                                                  answer  \
# 0                                            探听对方的意思或反应
# 1                                是计算机程序解决散列表冲突时所采取的一种策略
# 2     是一门面向过程的、抽象化的通用程序设计语言，广泛应用于底层开发。C语言能以简易的方式编译、处...
# 3     要从右到左用二进制的每个数去乘以2的相应次方，小数点后则是从左往右，如果首位是0就表示正整数...
# 4     是一门普通高等学校本科专业，属于计算机类专业，基本修业年限为四年，授予工学或理学学士学位；2...
# ...                                                 ...
# 1867  1、运算速度快：计算机系统的运算速度可以达到每秒万亿次。 2、计算精确度高：计算机的计算 精...
# 1868  指一个抽象的机器，即将人们使用纸笔进行数学运算的过程进行抽象，由一个虚拟的机器替代人类进行数学运算
# 1869  是一组主管并控制计算机操作、运用和运行硬件、软件资源和提供公共服务来组织用户交互的相互关联的...
# 1870   在控制台树中，单击 “计算机配置 ”，单击 “Windows 设置” ，然后单击 “安全设置 ”
# 1871  FTP服务器的安全配置（1）停止默认FTP站点打开“开始”“管理工具”“Internet信息...
#
#                                               knowledge
# 0     ['向外探索月球 探索群星然后将镜头扭转回来  开始看到了地球和自我这就是反思性的转折  扭...
# 1     ['在上一节 我们已经介绍了排解散列冲突的基本方法大抵说来 无非封闭定址和开放定址两类大的层...
# 2     ['Ritchie（理察德）开始和Thompson（汤普森）合作开发UNIX将B语言改造成C...
# 3     ['大家好这一讲我们来学习计算机中的数制以及它们之间的转换我们人类习惯的是十进制计数而计算机...
# 4     ['not technology”因此 从教学内容设计上我们认为至少应该包含以下两大部分一是...
# ...                                                 ...
# 1867  ['大家好这一节我们介绍计算机及计算的本质特征对于初学者来说很多教科书都在第一章中介绍计算机...
# 1868  ['欢迎同学们来到《软件理论基础》MOOC课堂我是清华大学教师罗贵明今天介绍的内容是图灵机的...
# 1869  ['操作系统是用于管理和控制计算机全部软件和硬件资源方便用户使用计算机的一组程序它的运行在硬...
# 1870  ['本节我们介绍Windows 7的系统安全包括用户管理 操作中心 系统还原以及BitLoc...
# 1871  ['下面进入这讲的案例设计环节根据校园网设计要求其中有个要求是按照安全系统要求建立端到端传输...
#
# [1872 rows x 4 columns]

# %% [markdown]
# # Thực hiện Interference với context lấy từ Pinecone

# %%
responses = []

# %%
from tqdm.auto import tqdm
from transformers import pipeline

question_answerer = pipeline(
  "question-answering",
  model="timpal0l/mdeberta-v3-base-squad2",
  device=0
)

for _, row in tqdm(qa.iterrows(), total=qa.shape[0]):
  query = row['question']
  query_embedded = db_tokenizer(query, padding=True, truncation=True, return_tensors='pt')

  # Compute token embeddings
  with torch.no_grad():
      model_output = db_model(**query_embedded)
      # Perform pooling. In this case, cls pooling.
      sentence_embeddings = model_output[0][:, 0]

  # normalize embeddings
  query_vector = torch.nn.functional.normalize(sentence_embeddings, p=2, dim=1)

  # Send the query to Pinecone
  xc = index.query(vector=query_vector.tolist(), top_k=5, include_metadata=True)

  # Use the text metadata from the query as context
  contexts = ""
  for data in xc['matches'][:]:
    contexts += data['metadata']['text']
  #contexts = xc['matches'][:][0]['metadata']['text']

  # Input the question and retrieved context into the model
  responses.append(question_answerer(question=row['question'], context=contexts))
responses
# Out:
#   0%|          | 0/1872 [00:00<?, ?it/s]
# {'matches': [{'id': 'FA9DE699C762C5539C33DC5901307461-6',
#               'metadata': {'text': '.'},
#               'score': 0.847676754,
#               'values': []},
#              {'id': '79DCF7F1D433CD319C33DC5901307461-0',
#               'metadata': {'text': '；'},
#               'score': 0.840048969,
#               'values': []},
#              {'id': 'C87C751F60BDF83C9C33DC5901307461-2',
#               'metadata': {'text': '）'},
#               'score': 0.835973144,
#               'values': []},
#              {'id': '7FA1DCCC871E1E3C9C33DC5901307461-1',
#               'metadata': {'text': '。'},
#               'score': 0.831995368,
#               'values': []},
#              {'id': '95C8D0FFD8AE22029C33DC5901307461-4',
#               'metadata': {'text': '？'},
#               'score': 0.829289675,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}
# {'matches': [{'id': 'B0B8D6A2442FD1059C33DC5901307461-15',
#               'metadata': {'text': 'Lines, Ltd.'},
#               'score': 0.798219,
#               'values': []},
#              {'id': 'FA9DE699C762C5539C33DC5901307461-6',
#               'metadata': {'text': '.'},
#               'score': 0.797040343,
#               'values': []},
#              {'id': 'D01393EE8D8759029C33DC5901307461-2',
#               'metadata': {'text': 'synthesized linker,'},
#               'score': 0.794475198,
#               'values': []},
#              {'id': '9305D4BB574893A89C33DC5901307461-0',
#               'metadata': {'text': 'III.'},
#               'score': 0.790397108,
#               'values': []},
#              {'id': 'AD52E684449C968F9C33DC5901307461-1',
#               'metadata': {'text': 'or diffracted,'},
#               'score': 0.789045036,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}
# {'matches': [{'id': '81A622B5AF0BABE39C33DC5901307461-3',
#               'metadata': {'text': 'C语言在Web开发领域应用较少在此只是对C语言的基本特点及其优缺点做了一个简要的介绍具体内容还需要在后面的学习过程中慢慢体会和领悟好了，同学们C语言的发展和特点我们就学习到这儿下节课再见'},
#               'score': 0.823864281,
#               'values': []},
#              {'id': '81A622B5AF0BABE39C33DC5901307461-0',
#               'metadata': {'text': '大家好我云南大学信息学院的丁海燕老师欢迎走进C语言程序设计课堂今天我们讲解的是C语言的发展和特点C语言是使用最广泛的语言之一可以说C语言的诞生是现代程序语言革命的起点是程序设计语言发展史中的一个里程碑自C语言出现后以C语言为根基的C++Java和C#等面向对象语言相继诞生并在各自领域大获成功根据TIOBE编程语言排行榜2019年3月公布的数据排名前10的为Java, '
#                                    'C, Python, C++,Visual Basic .NET, C#, '
#                                    'JavaScript,PHP, SQL 和 '
#                                    'Objective-CC语言位列第2我们再来看2002-2018年TOP '
#                                    '10编程语言 TIOBE '
#                                    '指数走势C语言多年来一直位于选用率榜单前列可以看出到今天C语言依旧在系统编程嵌入式编程等领域占据着统治地位这也就是为什么我们要学习C语言1.C语言至今仍然流行的原因是它无处不在靠近硬件，被用于开发其它语言和操作系统2.通过学习C语言可从系统级上更好的理解程序的工作原理3.大学应该继续教C语言它是一种非常重要的基础性语言要求完全理解整个技术栈4.学会C语言后学生将能更深入的理解计算机下面我们来看一下C语言的发展历程1963年剑桥大学推出了CPL1967年剑桥大学的Martin '
#                                    'Richards（马丁·理察德）把CPL语言改进为BCPL语言1970 年 '
#                                    '贝尔实验室 Ken Thompson（肯 '
#                                    '汤普森）将BCPL语言改造成B语言1972年，Dennis M.'},
#               'score': 0.786842,
#               'values': []},
#              {'id': '7E2A850329DE05599C33DC5901307461-0',
#               'metadata': {'text': '本学期我们的C语言程序设计课程上半部分就要结束了感谢大家的一路相伴也感谢同行朋友们的关注和支持下学期我们将继续与大家同行朋友们\u3000'
#                                    '再见'},
#               'score': 0.785638511,
#               'values': []},
#              {'id': '81A622B5AF0BABE39C33DC5901307461-1',
#               'metadata': {'text': 'Ritchie（理察德）开始和Thompson（汤普森）合作开发UNIX将B语言改造成C语言1983年，美国国家标准局（ANSI）成立了一个委员会，来制定C语言标准1989年，C语言标准被批准称为ANSI '
#                                    'C，即C891990年，国际标准化组织（ISO）接受ANSI C为ISO '
#                                    'C的标准1999年，ISO '
#                                    '对C语言标准修订并命名为ISO/IEC9899:1999即C992011年ISO正式发布C语言新标准C11经过这50多年的发展C语言的特点又会是什么样的呢低级的高级语言从C语言的处理方式来看它属于高级语言但从性能和控制来看它将高级语言的基本结构和语句与低级语言的实用性相结合从总体上来说可将C语言视为介于汇编语言和高级语言之间的一种语言结构式语言C语言是以函数形式提供给用户的它本身只提供必要的语言特性这些函数不是作为C语言核心出现可方便的调用并具有多种循环条件语句控制程序流向从而使程序完全结构化功能齐全具有各种各样的数据类型并引入了指针概念可使程序效率更高而且计算功能逻辑判断功能也比较强大可以实现决策目的的游戏C语言兼容性、可移植性强，应用广C语言对编写所需的硬件环境兼容性优于其它高级语言适用于多种操作系统如Windows、DOS、UNIX等等也适用于多种机型保留了指针可以直接进行靠近硬件的操作但是C的指针操作不作保护也给它带来了很多不安全的因素C++在这方面做了改进在保留了指针操作的同时又增强了安全性受到了一些用户的支持由于这些改进增加了语言的复杂度也为另一部分用户所诟病Java则吸取了C++的教训取消了指针操作也取消了C++改进中一些备受争议的地方在安全性和适合性方面均取得良好的效果但其本身解释在虚拟机中运行运行效率低于C++/CC语言文件由数据序列组成可以构成二进制文件或文本文件以上这6点就是C语言的特点也是C语言的魅力所在接下来我们一起看看C的优点1.简洁紧凑、灵活方便C语言一共只有32个关键字9种控制语句，'},
#               'score': 0.78210634,
#               'values': []},
#              {'id': 'A37248CD3049C97B9C33DC5901307461-3',
#               'metadata': {'text': 'B, C,'},
#               'score': 0.780746102,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}
# [{'score': 0.00017447536811232567, 'start': 0, 'end': 5, 'answer': '.；）。？'},
#  {'score': 1.3109050087223295e-05,
#   'start': 6,
#   'end': 49,
#   'answer': ' Ltd..synthesized linker,III.or diffracted,'},
#  {'score': 0.5196314454078674,
#   'start': 1290,
#   'end': 1609,
#   'answer': '多种操作系统如Windows、DOS、UNIX等等也适用于多种机型保留了指针可以直接进行靠近硬件的操作但是C的指针操作不作保护也给它带来了很多不安全的因素C++在这方面做了改进在保留了指针操作的同时又增强了安全性受到了一些用户的支持由于这些改进增加了语言的复杂度也为另一部分用户所诟病Java则吸取了C++的教训取消了指针操作也取消了C++改进中一些备受争议的地方在安全性和适合性方面均取得良好的效果但其本身解释在虚拟机中运行运行效率低于C++/CC语言文件由数据序列组成可以构成二进制文件或文本文件以上这6点就是C语言的特点也是C语言的魅力所在接下来我们一起看看C的优点1.简洁紧凑、灵活方便C语言一共只有32个关键字9种控制语句，B,'}]

# %% [markdown]
# ## Evaluation using ROUGE metrics

# %%
# Load saved answers
final = pd.read_excel('/content/drive/MyDrive/Nhom_2/Nhóm 2.2/Đồ án/Models/timpal0l-mdeberta-v3-base-squad2.xlsx',header=None)

# %%
# !git clone https://github.com/JialeGuo/py_rouge_zh --quiet
# %cd py_rouge_zh
# !python setup.py install --quiet
# Out:
# /content/py_rouge_zh/py_rouge_zh
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating py_rouge_zh.egg-info
# writing py_rouge_zh.egg-info/PKG-INFO
# writing dependency_links to py_rouge_zh.egg-info/dependency_links.txt
# writing top-level names to py_rouge_zh.egg-info/top_level.txt
# writing manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# reading manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/rouge_zh
# copying rouge_zh/__init__.py -> build/lib/rouge_zh
# copying rouge_zh/rouge_zh.py -> build/lib/rouge_zh
# copying rouge_zh/example.py -> build/lib/rouge_zh
# copying rouge_zh/wordnet_key_value.txt -> build/lib/rouge_zh
# copying rouge_zh/wordnet_key_value_special_cases.txt -> build/lib/rouge_zh
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/__init__.py -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/rouge_zh.py -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/wordnet_key_value.txt -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/wordnet_key_value_special_cases.txt -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/example.py -> build/bdist.linux-x86_64/egg/rouge_zh
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/rouge_zh.py to rouge_zh.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/example.py to example.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/py_rouge_zh-1.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing py_rouge_zh-1.1-py3.10.egg
# removing '/usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg' (and everything under it)
# creating /usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg
# Extracting py_rouge_zh-1.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# py-rouge-zh 1.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg
# Processing dependencies for py-rouge-zh==1.1
# Finished processing dependencies for py-rouge-zh==1.1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import rouge_zh

evaluator = rouge_zh.Rouge(metrics=['rouge-n'],
                           max_n=2,
                           length_limit_type='words',
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)

scores = evaluator.get_scores(qa['answer'].tolist(), final[0].to_list())
print(scores)
# Out:
# {'rouge-1': {'f': 0.0004740501350422493, 'p': 0.0005628328997894216, 'r': 0.000660836820192804}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}}

# %%
import rouge_zh

evaluator = rouge_zh.Rouge(metrics=['rouge-l'],
                           limit_length=True,
                           length_limit=100,
                           length_limit_type='words',
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)


scores = evaluator.get_scores(qa['answer'].tolist(), final[0].to_list())
print(scores)
# Out:
# {'rouge-l': {'f': 0.0004740501350422493, 'p': 0.0005628328997894216, 'r': 0.000660836820192804}}

# %% [markdown]
# # Thực hiện Interference dữ liệu Knowledge trong file `vta_qa.csv`

# %%
responses = []

# %%
from tqdm.auto import tqdm
from transformers import pipeline

question_answerer = pipeline(
  "question-answering",
  model="timpal0l/mdeberta-v3-base-squad2",
  device=0
)

for _, row in tqdm(qa.iterrows(), total=qa.shape[0]):
    responses.append(question_answerer(question=row['question'], context=row['knowledge']))
responses[0:3]
# Out:
#   0%|          | 0/1872 [00:00<?, ?it/s]
# [{'score': 0.11376631259918213,
#   'start': 1576,
#   'end': 2127,
#   'answer': "验，那么他们在测试后的受访中会被施压，被要求招供。第二种的测谎实验称为有罪知识测验。这个测验的目的在于确定嫌疑人是否认识某个特别类型的犯罪，而他们自己并不愿意展示。例如，让我们想象一下如下场景：一个嫌疑人用一把刀杀死一个人。他们会在访谈中否定这个，然后测谎仪检测者则会向嫌疑人展示一系列的刀具，包括杀死受害者所用的那把刀。对于每把刀，检测者会问嫌疑人他是否认识这把刀。在这种情况下，无辜的嫌疑人和有罪的嫌疑人都会否定认得这把刀。不过两者的不同点在于，有罪的嫌疑人会在看到犯罪现场使用的正确的刀具时展示出生理反应升高的数据。对于无辜的嫌疑人，所有刀具能产生相同的反应，因为这些刀具之前都没有见过。显而易见的是，如果你获得了一种证据，你只能利用这种实验版本，你可以向嫌疑人展示，而这个证据还没有被媒体报道。那么这些实验的可靠性如何？虽然某些提供测谎仪的公司声称他们的测谎仪准确，但是测谎仪的准确率各不相同。正如你看到的，由于这种准确率看起来要比那些依靠非言语行为的看起来更好，不过这些测谎仪的结果并非如某些人所认为的那么好，并且远不能达到100%的准确率。你还能看到这种准确性取决于你是试图测试真相还是谎言，而对于测谎的关键作用，对于犯罪知识测验，准确性会下降到一些水平，这种水平并不会比偶然测验更好。',"},
#  {'score': 0.00380075816065073,
#   'start': 1497,
#   'end': 2158,
#   'answer': '再把这个电量转换成数字量最后到计算机当中进行处理显示出来那么下面我们看到一个简单的测试系统如何测试温度的实际上也是要经过上述这些部分转换之后才能得到具体的温度那么对于测试系统它的基本要求而言我们可以看一看测试系统的输出信号它是能够真实地反映被测的物理量那么也就是指的是输入信号的变化过程那么它还要不使信号发生畸变这样的话就实现了不失真的测量的过程那么我们可以看看系统的传递或者是传输的特性是指什么呢是指系统的输出与输入量之间的变换或者是运算的关系我们把它称之为系统的传递特性下面我们看看信号与系统之间的关系那么信号和系统之间是紧密相关的当被测的物理量也就是信号作用到系统当中的时候系统在输入信号也就是输入激励的时候驱动下要对它进行加工并经过加工后的信号要把它输出出来输出信号的质量必定“不好于”输入信号的质量这是可以理解的因为它要经过中间的环节那么受的影响主要是什么呢是受测试系统的特性的影响另外呢是受信号传输过程中干扰的影响这两个方面都是使输出的信号质量一定不好于输入信号质量的最重要的因素那么接下来我们看看测试系统与其输入、输出之间的三种关系第一种是已知输入量和系统的传递特性我们来求系统的输出量第二种是已知输入和输出量求系统的传递特性第三种是已知系统的传递特性和输出量来求系统的输入量那么当然希望输入和输出之间是一种一一对应的确定的关系因此我们要求系统的传递特性它是一个线性的这样才能够实现输入和输出之间是一一对应的确定关系那么对于静态的测量而言系统的线性特性要求并非是必须的那我们要采取曲线的校正和补偿技术来作一个'},
#  {'score': 0.3148339092731476,
#   'start': 826,
#   'end': 1012,
#   'answer': " '大家好我云南大学信息学院的丁海燕老师欢迎走进C语言程序设计课堂今天我们讲解的是C语言的发展和特点C语言是使用最广泛的语言之一可以说C语言的诞生是现代程序语言革命的起点是程序设计语言发展史中的一个里程碑自C语言出现后以C语言为根基的C++Java和C#等面向对象语言相继诞生并在各自领域大获成功根据TIOBE编程语言排行榜2019年3月公布的数据排名前10的为Java,"}]

# %%
# Export saved answer to file

import csv
answers = []
for res in responses:
	answers.append(res['answer'])
final = pd.DataFrame(answers)
final.to_excel('/content/drive/MyDrive/Nhom_2/Nhóm 2.2/Đồ án/Models/timpal0l-mdeberta-v3-base-squad2.xlsx',header=False, index=False)

# %% [markdown]
# ## Evaluation using ROUGE metrics

# %%
# Load saved answers
final = pd.read_excel('/content/drive/MyDrive/Nhom_2/Nhóm 2.2/Đồ án/Models/timpal0l-mdeberta-v3-base-squad2.xlsx',header=None)

# %%
# !git clone https://github.com/JialeGuo/py_rouge_zh --quiet
# %cd py_rouge_zh
# !python setup.py install --quiet
# Out:
# /content/py_rouge_zh/py_rouge_zh
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating py_rouge_zh.egg-info
# writing py_rouge_zh.egg-info/PKG-INFO
# writing dependency_links to py_rouge_zh.egg-info/dependency_links.txt
# writing top-level names to py_rouge_zh.egg-info/top_level.txt
# writing manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# reading manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'py_rouge_zh.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/rouge_zh
# copying rouge_zh/__init__.py -> build/lib/rouge_zh
# copying rouge_zh/rouge_zh.py -> build/lib/rouge_zh
# copying rouge_zh/example.py -> build/lib/rouge_zh
# copying rouge_zh/wordnet_key_value.txt -> build/lib/rouge_zh
# copying rouge_zh/wordnet_key_value_special_cases.txt -> build/lib/rouge_zh
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/__init__.py -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/rouge_zh.py -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/wordnet_key_value.txt -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/wordnet_key_value_special_cases.txt -> build/bdist.linux-x86_64/egg/rouge_zh
# copying build/lib/rouge_zh/example.py -> build/bdist.linux-x86_64/egg/rouge_zh
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/rouge_zh.py to rouge_zh.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rouge_zh/example.py to example.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying py_rouge_zh.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/py_rouge_zh-1.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing py_rouge_zh-1.1-py3.10.egg
# removing '/usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg' (and everything under it)
# creating /usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg
# Extracting py_rouge_zh-1.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# py-rouge-zh 1.1 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/py_rouge_zh-1.1-py3.10.egg
# Processing dependencies for py-rouge-zh==1.1
# Finished processing dependencies for py-rouge-zh==1.1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import rouge_zh

evaluator = rouge_zh.Rouge(metrics=['rouge-n'],
                           max_n=2,
                           length_limit_type='words',
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)

scores = evaluator.get_scores(qa['answer'].tolist(), final[0].to_list())
print(scores)
# Out:
# {'rouge-1': {'f': 0.0004740501350422493, 'p': 0.0005628328997894216, 'r': 0.000660836820192804}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}}

# %%
import rouge_zh

evaluator = rouge_zh.Rouge(metrics=['rouge-l'],
                           limit_length=True,
                           length_limit=100,
                           length_limit_type='words',
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)


scores = evaluator.get_scores(qa['answer'].tolist(), final[0].to_list())
print(scores)
# Out:
# {'rouge-l': {'f': 0.0004740501350422493, 'p': 0.0005628328997894216, 'r': 0.000660836820192804}}
